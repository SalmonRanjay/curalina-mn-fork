# %% [markdown]
# # Bundle and substitution validation
#
# Status: experiment workbook, not implemented or evaluated.
#
# Can a bounded solver enforce all declared constraints?

# %% [markdown]
# ## Prerequisites
#
# Real furniture records for relevance evidence; labelled synthetic fixtures allowed for logic tests.
#
# Read the corresponding guide and model selection guide before implementation. Use the kernel described in the local setup guide.

# %%
from pathlib import Path
import json

experiment = {"name": '03_bundle_and_substitutions', "status": "not_run", "metrics": None}
experiment

# %% [markdown]
# ## Input contract and split
#
# Record source hashes, IDs, permissions and development/held-out allocation before tuning. Missing inputs are blockers, not values to invent.

# %% [markdown]
# ## Step 1
#
# Specify required categories, quantities and approved clearance rules.
#
# Implement this step below. Record what changed, why, and evidence from the output. Keep transformations suitable for later extraction into the owning package.

# %% [markdown]
# ## Step 2
#
# Run feasible and infeasible layouts with quantity-aware decimal budgets.
#
# Implement this step below. Record what changed, why, and evidence from the output. Keep transformations suitable for later extraction into the owning package.

# %% [markdown]
# ## Step 3
#
# Swap one product and recompute total, compatibility and layout.
#
# Implement this step below. Record what changed, why, and evidence from the output. Keep transformations suitable for later extraction into the owning package.

# %% [markdown]
# ## Step 4
#
# Create characterization cases for later pure domain functions.
#
# Implement this step below. Record what changed, why, and evidence from the output. Keep transformations suitable for later extraction into the owning package.

# %% [markdown]
# ## Required outputs
#
# - bundle_cases.json
# - constraint_results.csv
#
# Use templates/experiment_report.md. Include failed attempts; leave unknown measurements null.

# %% [markdown]
# ## Promotion decision
#
# Artwork data alone cannot pass complete-room recommendation feasibility.
#
# Record adopt/revise/reject, owner, reviewer and evidence. Restart and run all implemented cells before submitting. An empty workbook is not a passed experiment.

# %% [markdown]
# ## Service extraction and unit tests
#
# Identify pure transforms, domain invariants, I/O adapters and model ports. Add deterministic unit cases including invalid inputs. Keep real inference tests in the separate GPU evaluation suite. Record package/notebook parity before exposing HTTP.
